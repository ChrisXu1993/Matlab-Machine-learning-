# %%
periodic_table={'Hydrogen':1,'Helium':2}
print(periodic_table)
# Out:
# {'Hydrogen': 1, 'Helium': 2}

# %%
carbon=periodic_table.setdefault('cabon',12)

# %%
carbon
# Out:
# 12

# %%
periodic_table
# Out:
# {'Hydrogen': 1, 'Helium': 2, 'cabon': 12}

# %%
from collections import defaultdict
periodic_table=defaultdict(int)

# %%
periodic_table['degf']
# Out:
# 0

# %%
from collections import defaultdict

# %%
def no_idea():
    return 'Hub?'

# %%
bestiary=defaultdict(no_idea)

# %%
bestiary['A']='Abominable Snowman'
bestiary['B']='Basilisk'
bestiary['A']
# Out:
# 'Abominable Snowman'

# %%
bestiary['d']
# Out:
# 'Hub?'

# %%
# by the way, you can use lambda to define your default-making function right inside the call

# %%
bestiary=defaultdict(lambda:'Huh')

# %%
bestiary['A']
# Out:
# 'Huh'

# %%
#Using int is one way to make your own counter:

# %%
from collections import defaultdict
food_counter=defaultdict(int)
for food in ['spam','spam','eggs','spam']:
    food_counter[food]+=1

for food, count in food_counter.items():
    print(food,count)
# Out:
# spam 3
# eggs 1

# %%
dict_counter={}#empty dictionary
for food in ['spam','spam','eggs','spam']:
    if not food in dict_counter:
        dict_counter[food]=0#给新来的一个 initialization
    dict_counter[food]+=1
    
for food, count in dict_counter.items():
    print(food,count)
# Out:
# spam 3
# eggs 1

# %%
#Order by key with OrderedDict
quotes={
    'Moe':'a wise guy,huh?',
    'Larry':'Ow!',
    'Curly':'Nyuk nyuk!',
      }

# %%
for stooge in quotes:
    print(stooge)
# Out:
# Moe
# Larry
# Curly

# %%
from collections import Counter
breakfast=['spam','eggs','spam','spam']
breakfast_counter=Counter(breakfast)
breakfast_counter
# Out:
# Counter({'spam': 3, 'eggs': 1})

# %%
breakfast_counter.most_common()
# Out:
# [('spam', 3), ('eggs', 1)]

# %%
lunch=['eggs','eggs','bacon']
lunch_counter=Counter(lunch)

# %%
lunch_counter
# Out:
# Counter({'eggs': 2, 'bacon': 1})

# %%
lunch_counter.most_common()
# Out:
# [('eggs', 2), ('bacon', 1)]

# %%
breakfast_counter+lunch_counter
# Out:
# Counter({'spam': 3, 'eggs': 3, 'bacon': 1})

# %%
breakfast_counter|lunch_counter
# Out:
# Counter({'spam': 3, 'eggs': 2, 'bacon': 1})

# %%
quotes
# Out:
# {'Moe': 'a wise guy,huh?', 'Larry': 'Ow!', 'Curly': 'Nyuk nyuk!'}

# %%
from collections import OrderedDict
OrderedDict(quotes)
# Out:
# OrderedDict([('Moe', 'a wise guy,huh?'),
#              ('Larry', 'Ow!'),
#              ('Curly', 'Nyuk nyuk!')])

# %%
def palindrome(word):
    from collections import deque
    dq=deque(word)
    while len(dq)>1:
        if dq.popleft()!=dq.pop():
            return False
    return True

# %%
def another_palindrome(word):
    return word==word[::-1]

another_palindrome('d')
# Out:
# True

# %%
#chain() runs through its arguments as though they were a single iterable
import itertools
for item in itertools.chain([1,2],['a','b']):
    print(item)
# Out:
# 1
# 2
# a
# b

# %%
import itertools
for item in itertools.cycle([1,2]):
    print(item)
# Out:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ...

# %%
import itertools
for item in itertools.accumulate([1,2,3,4]):
    print(item)
# Out:
# 1
# 3
# 6
# 10

# %%
import itertools
def reduction(a,b):
    return a-b

for item in itertools.accumulate([1,2,3,4,5],reduction):
    print(item)
# Out:
# 1
# -1
# -4
# -8
# -13

# %%
from pprint import pprint
quotes=OrderedDict([
    ('Moe','A wise guy, huh?'),
    ('Larry','Ow'),
    ('Curly','Nyuk'),
    ])

# %%
pprint(quotes)
# Out:
# OrderedDict([('Moe', 'A wise guy, huh?'), ('Larry', 'Ow'), ('Curly', 'Nyuk')])
